# %% [markdown]
# Time Series forecasting
# This project will let you practice your new skills on dealing with time series forecasting, by creating a cpu usage anomaly detection model.

# %%
# !pip install numpy
# !pip install pandas
# !pip install pyflux
# !pip install os
# Out:
# Collecting numpy
#   Downloading numpy-1.23.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 88.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
# Successfully installed numpy-1.23.1
#
# [notice] A new release of pip available: 22.2 -> 22.2.1
# [notice] To update, run: pip install --upgrade pip
# Collecting pandas
#   Downloading pandas-1.4.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 94.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas) (1.23.1)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 kB 84.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.4.3 pytz-2022.1
#
# [notice] A new release of pip available: 22.2 -> 22.2.1
# [notice] To update, run: pip install --upgrade pip
# Collecting pyflux
#   Downloading pyflux-0.4.15.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.6 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pyflux) (1.23.1)
# Requirement already satisfied: pandas in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pyflux) (1.4.3)
# Collecting scipy
#   Downloading scipy-1.9.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 36.4 MB/s eta 0:00:0000:0100:01
# Collecting numdifftools
#   Downloading numdifftools-0.9.40-py2.py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 36.8 MB/s eta 0:00:00
# Collecting patsy
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.7/233.7 kB 72.1 MB/s eta 0:00:00
# Collecting algopy>=0.4
#   Downloading algopy-0.5.7.zip (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.5/189.5 kB 54.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting statsmodels>=0.6
#   Downloading statsmodels-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 100.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas->pyflux) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas->pyflux) (2.8.2)
# Requirement already satisfied: six in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from patsy->pyflux) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels>=0.6->numdifftools->pyflux) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from packaging>=21.3->statsmodels>=0.6->numdifftools->pyflux) (3.0.9)
# Building wheels for collected packages: pyflux, algopy
#   Building wheel for pyflux (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [567 lines of output]
#       /tmp/pip-install-6dab18eh/pyflux_4cf0b35448234aa6b9c4bbb97ffc6914/setup.py:62: DeprecationWarning:
#
#         `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#         of the deprecation of `distutils` itself. It will be removed for
#         Python >= 3.12. For older Python versions it will remain present.
#         It is recommended to use `setuptools < 60.0` for those Python versions.
#         For more details, see:
#           https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#         from numpy.distutils.core import setup
#       running bdist_wheel
#       running build
#       running config_cc
#       INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       INFO: build_src
#       INFO: building extension "pyflux.__check_build._check_build" sources
#       INFO: building extension "pyflux.arma.arma_recursions" sources
#       INFO: building extension "pyflux.arma.nn_architecture" sources
#       INFO: building extension "pyflux.families.gas_recursions" sources
#       INFO: building extension "pyflux.families.poisson_kalman_recursions" sources
#       INFO: building extension "pyflux.garch.garch_recursions" sources
#       INFO: building extension "pyflux.gas.gas_core_recursions" sources
#       INFO: building extension "pyflux.gpnarx.kernel_routines" sources
#       INFO: building extension "pyflux.inference.metropolis_sampler" sources
#       INFO: building extension "pyflux.inference.bbvi_routines" sources
#       INFO: building extension "pyflux.ssm.kalman" sources
#       INFO: building extension "pyflux.var.var_recursions" sources
#       INFO: build_src: building npy-pkg config files
#       /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-38
#       creating build/lib.linux-x86_64-cpython-38/pyflux
#       copying pyflux/setup.py -> build/lib.linux-x86_64-cpython-38/pyflux
#       copying pyflux/latent_variables.py -> build/lib.linux-x86_64-cpython-38/pyflux
#       copying pyflux/tsm.py -> build/lib.linux-x86_64-cpython-38/pyflux
#       copying pyflux/data_check.py -> build/lib.linux-x86_64-cpython-38/pyflux
#       copying pyflux/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux
#       copying pyflux/results.py -> build/lib.linux-x86_64-cpython-38/pyflux
#       copying pyflux/covariances.py -> build/lib.linux-x86_64-cpython-38/pyflux
#       creating build/lib.linux-x86_64-cpython-38/pyflux/__check_build
#       copying pyflux/__check_build/setup.py -> build/lib.linux-x86_64-cpython-38/pyflux/__check_build
#       copying pyflux/__check_build/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux/__check_build
#       creating build/lib.linux-x86_64-cpython-38/pyflux/arma
#       copying pyflux/arma/nnarx.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma
#       copying pyflux/arma/setup.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma
#       copying pyflux/arma/nnar.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma
#       copying pyflux/arma/arma.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma
#       copying pyflux/arma/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma
#       copying pyflux/arma/arimax.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma
#       creating build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arima_skewt.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arima_normal.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arima_cauchy.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arima_exponential.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arimax_laplace.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arimax_exponential.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arimax_normal.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arimax_inference.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arimax_cauchy.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arima_poisson.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arimax_t.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arimax_skewt.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arima_laplace.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arima_inference.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arima_t.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       copying pyflux/arma/tests/test_arimax_poisson.py -> build/lib.linux-x86_64-cpython-38/pyflux/arma/tests
#       creating build/lib.linux-x86_64-cpython-38/pyflux/ensembles
#       copying pyflux/ensembles/mixture_of_experts.py -> build/lib.linux-x86_64-cpython-38/pyflux/ensembles
#       copying pyflux/ensembles/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux/ensembles
#       creating build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/inverse_wishart.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/family.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/exponential.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/setup.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/poisson.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/t.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/cauchy.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/skewt.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/normal.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/flat.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/laplace.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/inverse_gamma.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       copying pyflux/families/truncated_normal.py -> build/lib.linux-x86_64-cpython-38/pyflux/families
#       creating build/lib.linux-x86_64-cpython-38/pyflux/garch
#       copying pyflux/garch/setup.py -> build/lib.linux-x86_64-cpython-38/pyflux/garch
#       copying pyflux/garch/segarch.py -> build/lib.linux-x86_64-cpython-38/pyflux/garch
#       copying pyflux/garch/garch.py -> build/lib.linux-x86_64-cpython-38/pyflux/garch
#       copying pyflux/garch/egarchmreg.py -> build/lib.linux-x86_64-cpython-38/pyflux/garch
#       copying pyflux/garch/egarch.py -> build/lib.linux-x86_64-cpython-38/pyflux/garch
#       copying pyflux/garch/lmegarch.py -> build/lib.linux-x86_64-cpython-38/pyflux/garch
#       copying pyflux/garch/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux/garch
#       copying pyflux/garch/segarchm.py -> build/lib.linux-x86_64-cpython-38/pyflux/garch
#       copying pyflux/garch/egarchm.py -> build/lib.linux-x86_64-cpython-38/pyflux/garch
#       creating build/lib.linux-x86_64-cpython-38/pyflux/gas
#       copying pyflux/gas/setup.py -> build/lib.linux-x86_64-cpython-38/pyflux/gas
#       copying pyflux/gas/gasllt.py -> build/lib.linux-x86_64-cpython-38/pyflux/gas
#       copying pyflux/gas/gasllm.py -> build/lib.linux-x86_64-cpython-38/pyflux/gas
#       copying pyflux/gas/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux/gas
#       copying pyflux/gas/scores.py -> build/lib.linux-x86_64-cpython-38/pyflux/gas
#       copying pyflux/gas/gasrank.py -> build/lib.linux-x86_64-cpython-38/pyflux/gas
#       copying pyflux/gas/gasreg.py -> build/lib.linux-x86_64-cpython-38/pyflux/gas
#       copying pyflux/gas/gas.py -> build/lib.linux-x86_64-cpython-38/pyflux/gas
#       copying pyflux/gas/gasx.py -> build/lib.linux-x86_64-cpython-38/pyflux/gas
#       creating build/lib.linux-x86_64-cpython-38/pyflux/gpnarx
#       copying pyflux/gpnarx/setup.py -> build/lib.linux-x86_64-cpython-38/pyflux/gpnarx
#       copying pyflux/gpnarx/kernels.py -> build/lib.linux-x86_64-cpython-38/pyflux/gpnarx
#       copying pyflux/gpnarx/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux/gpnarx
#       copying pyflux/gpnarx/gpnarx.py -> build/lib.linux-x86_64-cpython-38/pyflux/gpnarx
#       creating build/lib.linux-x86_64-cpython-38/pyflux/inference
#       copying pyflux/inference/stoch_optim.py -> build/lib.linux-x86_64-cpython-38/pyflux/inference
#       copying pyflux/inference/setup.py -> build/lib.linux-x86_64-cpython-38/pyflux/inference
#       copying pyflux/inference/bbvi.py -> build/lib.linux-x86_64-cpython-38/pyflux/inference
#       copying pyflux/inference/norm_post_sim.py -> build/lib.linux-x86_64-cpython-38/pyflux/inference
#       copying pyflux/inference/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux/inference
#       copying pyflux/inference/metropolis_hastings.py -> build/lib.linux-x86_64-cpython-38/pyflux/inference
#       creating build/lib.linux-x86_64-cpython-38/pyflux/output
#       copying pyflux/output/tableprinter.py -> build/lib.linux-x86_64-cpython-38/pyflux/output
#       copying pyflux/output/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux/output
#       creating build/lib.linux-x86_64-cpython-38/pyflux/ssm
#       copying pyflux/ssm/nllm.py -> build/lib.linux-x86_64-cpython-38/pyflux/ssm
#       copying pyflux/ssm/llt.py -> build/lib.linux-x86_64-cpython-38/pyflux/ssm
#       copying pyflux/ssm/local_level.py -> build/lib.linux-x86_64-cpython-38/pyflux/ssm
#       copying pyflux/ssm/setup.py -> build/lib.linux-x86_64-cpython-38/pyflux/ssm
#       copying pyflux/ssm/dar.py -> build/lib.linux-x86_64-cpython-38/pyflux/ssm
#       copying pyflux/ssm/dynlin.py -> build/lib.linux-x86_64-cpython-38/pyflux/ssm
#       copying pyflux/ssm/nllt.py -> build/lib.linux-x86_64-cpython-38/pyflux/ssm
#       copying pyflux/ssm/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux/ssm
#       copying pyflux/ssm/llm.py -> build/lib.linux-x86_64-cpython-38/pyflux/ssm
#       copying pyflux/ssm/ndynlin.py -> build/lib.linux-x86_64-cpython-38/pyflux/ssm
#       copying pyflux/ssm/local_trend.py -> build/lib.linux-x86_64-cpython-38/pyflux/ssm
#       copying pyflux/ssm/dynamic_glm.py -> build/lib.linux-x86_64-cpython-38/pyflux/ssm
#       creating build/lib.linux-x86_64-cpython-38/pyflux/tests
#       copying pyflux/tests/nhst.py -> build/lib.linux-x86_64-cpython-38/pyflux/tests
#       copying pyflux/tests/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux/tests
#       creating build/lib.linux-x86_64-cpython-38/pyflux/var
#       copying pyflux/var/setup.py -> build/lib.linux-x86_64-cpython-38/pyflux/var
#       copying pyflux/var/var.py -> build/lib.linux-x86_64-cpython-38/pyflux/var
#       copying pyflux/var/__init__.py -> build/lib.linux-x86_64-cpython-38/pyflux/var
#       running build_ext
#       INFO: customize UnixCCompiler
#       INFO: customize UnixCCompiler using build_ext
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-march=native)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       creating /tmp/tmpfjbzwtb8/home
#       creating /tmp/tmpfjbzwtb8/home/gitpod
#       creating /tmp/tmpfjbzwtb8/home/gitpod/.pyenv
#       creating /tmp/tmpfjbzwtb8/home/gitpod/.pyenv/versions
#       creating /tmp/tmpfjbzwtb8/home/gitpod/.pyenv/versions/3.8.13
#       creating /tmp/tmpfjbzwtb8/home/gitpod/.pyenv/versions/3.8.13/lib
#       creating /tmp/tmpfjbzwtb8/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8
#       creating /tmp/tmpfjbzwtb8/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages
#       creating /tmp/tmpfjbzwtb8/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy
#       creating /tmp/tmpfjbzwtb8/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/distutils
#       creating /tmp/tmpfjbzwtb8/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/distutils/checks
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-march=native'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-O3)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-O3'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-Werror)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-Werror'
#       INFO: CCompilerOpt.__init__[1782] : check requested baseline
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-msse)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-msse2)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse2'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'SSE2' with flags (-msse -msse2)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -Werror'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'SSE' with flags (-msse -msse2)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -Werror'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-msse3)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse3'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'SSE3' with flags (-msse -msse2 -msse3)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -Werror'
#       INFO: CCompilerOpt.__init__[1791] : check requested dispatch-able features
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mssse3)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mssse3'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-msse4.1)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse4.1'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mpopcnt)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mpopcnt'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-msse4.2)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse4.2'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mavx)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mavx'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mf16c)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mf16c'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'F16C' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -Werror'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'SSSE3' with flags (-msse -msse2 -msse3 -mssse3)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -Werror'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'AVX' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -Werror'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mfma)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mfma'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mavx2)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mavx2'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mavx512f -mno-mmx)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mavx512f -mno-mmx'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mavx512cd)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mavx512cd'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'AVX512CD' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -Werror'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'FMA3' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -Werror'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mavx512vl -mavx512bw -mavx512dq)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mavx512vl -mavx512bw -mavx512dq'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'AVX512_SKX' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512vl -mavx512bw -mavx512dq)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512vl -mavx512bw -mavx512dq -Werror'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'SSE42' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -Werror'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'AVX512F' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -Werror'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'POPCNT' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -Werror'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'AVX2' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mavx2)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mavx2 -Werror'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'SSE41' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -Werror'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mavx512ifma -mavx512vbmi)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mavx512ifma -mavx512vbmi'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'AVX512_CNL' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512vl -mavx512bw -mavx512dq -mavx512ifma -mavx512vbmi)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512vl -mavx512bw -mavx512dq -mavx512ifma -mavx512vbmi -Werror'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mavx512er -mavx512pf)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mavx512er -mavx512pf'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'AVX512_KNL' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512er -mavx512pf)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512er -mavx512pf -Werror'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mavx512vnni)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mavx512vnni'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'AVX512_CLX' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512vl -mavx512bw -mavx512dq -mavx512vnni)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512vl -mavx512bw -mavx512dq -mavx512vnni -Werror'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mavx512vbmi2 -mavx512bitalg -mavx512vpopcntdq)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mavx512vbmi2 -mavx512bitalg -mavx512vpopcntdq'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'AVX512_ICL' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512vl -mavx512bw -mavx512dq -mavx512vnni -mavx512ifma -mavx512vbmi -mavx512vbmi2 -mavx512bitalg -mavx512vpopcntdq)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512vl -mavx512bw -mavx512dq -mavx512vnni -mavx512ifma -mavx512vbmi -mavx512vbmi2 -mavx512bitalg -mavx512vpopcntdq -Werror'
#       INFO: CCompilerOpt.cc_test_flags[1073] : testing flags (-mavx5124fmaps -mavx5124vnniw -mavx512vpopcntdq)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-mavx5124fmaps -mavx5124vnniw -mavx512vpopcntdq'
#       INFO: CCompilerOpt.feature_test[1547] : testing feature 'AVX512_KNM' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512er -mavx512pf -mavx5124fmaps -mavx5124vnniw -mavx512vpopcntdq)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512er -mavx512pf -mavx5124fmaps -mavx5124vnniw -mavx512vpopcntdq -Werror'
#       INFO: CCompilerOpt.__init__[1803] : skip features (SSE SSE2 SSE3) since its part of baseline
#       INFO: CCompilerOpt.__init__[1807] : initialize targets groups
#       INFO: CCompilerOpt.__init__[1809] : parse target group simd_test
#       INFO: CCompilerOpt._parse_target_tokens[2020] : skip targets (VXE2 VSX ASIMD VX FMA4 VSX4 VXE VSX2 XOP NEON VSX3) not part of baseline or dispatch-able features
#       INFO: CCompilerOpt._parse_policy_not_keepbase[2132] : skip baseline features (SSE2)
#       INFO: CCompilerOpt.generate_dispatch_header[2353] : generate CPU dispatch header: (build/src.linux-x86_64-3.8/numpy/distutils/include/npy_cpu_dispatch_config.h)
#       WARN: CCompilerOpt.generate_dispatch_header[2362] : dispatch header dir build/src.linux-x86_64-3.8/numpy/distutils/include does not exist, creating it
#       INFO: CCompilerOpt.feature_extra_checks[1627] : Testing extra checks for feature 'AVX512F' (AVX512F_REDUCE)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -Werror'
#       INFO: CCompilerOpt.feature_extra_checks[1627] : Testing extra checks for feature 'AVX512_SKX' (AVX512BW_MASK AVX512DQ_MASK)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512vl -mavx512bw -mavx512dq -Werror'
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512vl -mavx512bw -mavx512dq -Werror'
#       INFO: building 'pyflux.__check_build._check_build' extension
#       INFO: compiling C sources
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       creating build/temp.linux-x86_64-cpython-38/pyflux
#       creating build/temp.linux-x86_64-cpython-38/pyflux/__check_build
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include -Ibuild/src.linux-x86_64-3.8/numpy/distutils/include -I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3'
#       INFO: gcc: pyflux/__check_build/_check_build.c
#       INFO: gcc -pthread -shared -L/home/gitpod/.pyenv/versions/3.8.13/lib -L/home/gitpod/.pyenv/versions/3.8.13/lib build/temp.linux-x86_64-cpython-38/pyflux/__check_build/_check_build.o -o build/lib.linux-x86_64-cpython-38/pyflux/__check_build/_check_build.cpython-38-x86_64-linux-gnu.so
#       INFO: building 'pyflux.arma.arma_recursions' extension
#       INFO: compiling C sources
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       creating build/temp.linux-x86_64-cpython-38/pyflux/arma
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include -Ibuild/src.linux-x86_64-3.8/numpy/distutils/include -I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3'
#       INFO: gcc: pyflux/arma/arma_recursions.c
#       In file included from /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/ndarraytypes.h:1948,
#                        from /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                        from /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                        from pyflux/arma/arma_recursions.c:274:
#       /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#          17 | #warning "Using deprecated NumPy API, disable it with " \
#             |  ^~~~~~~
#       pyflux/arma/arma_recursions.c: In function ‘PyInit_arma_recursions’:
#       pyflux/arma/arma_recursions.c:17748:3: warning: ‘tp_print’ is deprecated [-Wdeprecated-declarations]
#       17748 |   __pyx_type___pyx_array.tp_print = 0;
#             |   ^~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/object.h:746,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/pytime.h:6,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/Python.h:85,
#                        from pyflux/arma/arma_recursions.c:4:
#       /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/cpython/object.h:260:30: note: declared here
#         260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#             |                              ^~~~~~~~
#       pyflux/arma/arma_recursions.c:17752:3: warning: ‘tp_print’ is deprecated [-Wdeprecated-declarations]
#       17752 |   __pyx_type___pyx_MemviewEnum.tp_print = 0;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/object.h:746,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/pytime.h:6,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/Python.h:85,
#                        from pyflux/arma/arma_recursions.c:4:
#       /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/cpython/object.h:260:30: note: declared here
#         260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#             |                              ^~~~~~~~
#       pyflux/arma/arma_recursions.c:17763:3: warning: ‘tp_print’ is deprecated [-Wdeprecated-declarations]
#       17763 |   __pyx_type___pyx_memoryview.tp_print = 0;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/object.h:746,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/pytime.h:6,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/Python.h:85,
#                        from pyflux/arma/arma_recursions.c:4:
#       /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/cpython/object.h:260:30: note: declared here
#         260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#             |                              ^~~~~~~~
#       pyflux/arma/arma_recursions.c:17772:3: warning: ‘tp_print’ is deprecated [-Wdeprecated-declarations]
#       17772 |   __pyx_type___pyx_memoryviewslice.tp_print = 0;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/object.h:746,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/pytime.h:6,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/Python.h:85,
#                        from pyflux/arma/arma_recursions.c:4:
#       /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/cpython/object.h:260:30: note: declared here
#         260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#             |                              ^~~~~~~~
#       pyflux/arma/arma_recursions.c: In function ‘__Pyx__ExceptionSave’:
#       pyflux/arma/arma_recursions.c:19331:21: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19331 |     *type = tstate->exc_type;
#             |                     ^~~~~~~~
#             |                     curexc_type
#       pyflux/arma/arma_recursions.c:19332:22: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19332 |     *value = tstate->exc_value;
#             |                      ^~~~~~~~~
#             |                      curexc_value
#       pyflux/arma/arma_recursions.c:19333:19: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19333 |     *tb = tstate->exc_traceback;
#             |                   ^~~~~~~~~~~~~
#             |                   curexc_traceback
#       pyflux/arma/arma_recursions.c: In function ‘__Pyx__ExceptionReset’:
#       pyflux/arma/arma_recursions.c:19340:24: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19340 |     tmp_type = tstate->exc_type;
#             |                        ^~~~~~~~
#             |                        curexc_type
#       pyflux/arma/arma_recursions.c:19341:25: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19341 |     tmp_value = tstate->exc_value;
#             |                         ^~~~~~~~~
#             |                         curexc_value
#       pyflux/arma/arma_recursions.c:19342:22: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19342 |     tmp_tb = tstate->exc_traceback;
#             |                      ^~~~~~~~~~~~~
#             |                      curexc_traceback
#       pyflux/arma/arma_recursions.c:19343:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19343 |     tstate->exc_type = type;
#             |             ^~~~~~~~
#             |             curexc_type
#       pyflux/arma/arma_recursions.c:19344:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19344 |     tstate->exc_value = value;
#             |             ^~~~~~~~~
#             |             curexc_value
#       pyflux/arma/arma_recursions.c:19345:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19345 |     tstate->exc_traceback = tb;
#             |             ^~~~~~~~~~~~~
#             |             curexc_traceback
#       pyflux/arma/arma_recursions.c: In function ‘__Pyx__GetException’:
#       pyflux/arma/arma_recursions.c:19400:24: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19400 |     tmp_type = tstate->exc_type;
#             |                        ^~~~~~~~
#             |                        curexc_type
#       pyflux/arma/arma_recursions.c:19401:25: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19401 |     tmp_value = tstate->exc_value;
#             |                         ^~~~~~~~~
#             |                         curexc_value
#       pyflux/arma/arma_recursions.c:19402:22: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19402 |     tmp_tb = tstate->exc_traceback;
#             |                      ^~~~~~~~~~~~~
#             |                      curexc_traceback
#       pyflux/arma/arma_recursions.c:19403:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19403 |     tstate->exc_type = local_type;
#             |             ^~~~~~~~
#             |             curexc_type
#       pyflux/arma/arma_recursions.c:19404:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19404 |     tstate->exc_value = local_value;
#             |             ^~~~~~~~~
#             |             curexc_value
#       pyflux/arma/arma_recursions.c:19405:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19405 |     tstate->exc_traceback = local_tb;
#             |             ^~~~~~~~~~~~~
#             |             curexc_traceback
#       pyflux/arma/arma_recursions.c: In function ‘__Pyx__ExceptionSwap’:
#       pyflux/arma/arma_recursions.c:19427:24: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19427 |     tmp_type = tstate->exc_type;
#             |                        ^~~~~~~~
#             |                        curexc_type
#       pyflux/arma/arma_recursions.c:19428:25: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19428 |     tmp_value = tstate->exc_value;
#             |                         ^~~~~~~~~
#             |                         curexc_value
#       pyflux/arma/arma_recursions.c:19429:22: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19429 |     tmp_tb = tstate->exc_traceback;
#             |                      ^~~~~~~~~~~~~
#             |                      curexc_traceback
#       pyflux/arma/arma_recursions.c:19430:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19430 |     tstate->exc_type = *type;
#             |             ^~~~~~~~
#             |             curexc_type
#       pyflux/arma/arma_recursions.c:19431:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19431 |     tstate->exc_value = *value;
#             |             ^~~~~~~~~
#             |             curexc_value
#       pyflux/arma/arma_recursions.c:19432:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19432 |     tstate->exc_traceback = *tb;
#             |             ^~~~~~~~~~~~~
#             |             curexc_traceback
#       In file included from /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/ndarrayobject.h:21,
#                        from /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                        from pyflux/arma/arma_recursions.c:274:
#       At top level:
#       /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/__multiarray_api.h:1477:1: warning: ‘_import_array’ defined but not used [-Wunused-function]
#        1477 | _import_array(void)
#             | ^~~~~~~~~~~~~
# ...
#       INFO: CCompilerOpt.generate_dispatch_header[2353] : generate CPU dispatch header: (build/src.linux-x86_64-3.8/numpy/distutils/include/npy_cpu_dispatch_config.h)
#       INFO: CCompilerOpt.feature_extra_checks[1627] : Testing extra checks for feature 'AVX512F' (AVX512F_REDUCE)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -Werror'
#       INFO: CCompilerOpt.feature_extra_checks[1627] : Testing extra checks for feature 'AVX512_SKX' (AVX512BW_MASK AVX512DQ_MASK)
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512vl -mavx512bw -mavx512dq -Werror'
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mno-mmx -mavx512cd -mavx512vl -mavx512bw -mavx512dq -Werror'
#       INFO: building 'pyflux.__check_build._check_build' extension
#       INFO: compiling C sources
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       creating build/temp.linux-x86_64-cpython-38/pyflux
#       creating build/temp.linux-x86_64-cpython-38/pyflux/__check_build
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include -Ibuild/src.linux-x86_64-3.8/numpy/distutils/include -I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3'
#       INFO: gcc: pyflux/__check_build/_check_build.c
#       INFO: gcc -pthread -shared -L/home/gitpod/.pyenv/versions/3.8.13/lib -L/home/gitpod/.pyenv/versions/3.8.13/lib build/temp.linux-x86_64-cpython-38/pyflux/__check_build/_check_build.o -o build/lib.linux-x86_64-cpython-38/pyflux/__check_build/_check_build.cpython-38-x86_64-linux-gnu.so
#       INFO: building 'pyflux.arma.arma_recursions' extension
#       INFO: compiling C sources
#       INFO: C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
#       creating build/temp.linux-x86_64-cpython-38/pyflux/arma
#       INFO: compile options: '-I/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include -Ibuild/src.linux-x86_64-3.8/numpy/distutils/include -I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c'
#       extra options: '-msse -msse2 -msse3'
#       INFO: gcc: pyflux/arma/arma_recursions.c
#       In file included from /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/ndarraytypes.h:1948,
#                        from /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                        from /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                        from pyflux/arma/arma_recursions.c:274:
#       /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#          17 | #warning "Using deprecated NumPy API, disable it with " \
#             |  ^~~~~~~
#       pyflux/arma/arma_recursions.c: In function ‘PyInit_arma_recursions’:
#       pyflux/arma/arma_recursions.c:17748:3: warning: ‘tp_print’ is deprecated [-Wdeprecated-declarations]
#       17748 |   __pyx_type___pyx_array.tp_print = 0;
#             |   ^~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/object.h:746,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/pytime.h:6,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/Python.h:85,
#                        from pyflux/arma/arma_recursions.c:4:
#       /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/cpython/object.h:260:30: note: declared here
#         260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#             |                              ^~~~~~~~
#       pyflux/arma/arma_recursions.c:17752:3: warning: ‘tp_print’ is deprecated [-Wdeprecated-declarations]
#       17752 |   __pyx_type___pyx_MemviewEnum.tp_print = 0;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/object.h:746,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/pytime.h:6,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/Python.h:85,
#                        from pyflux/arma/arma_recursions.c:4:
#       /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/cpython/object.h:260:30: note: declared here
#         260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#             |                              ^~~~~~~~
#       pyflux/arma/arma_recursions.c:17763:3: warning: ‘tp_print’ is deprecated [-Wdeprecated-declarations]
#       17763 |   __pyx_type___pyx_memoryview.tp_print = 0;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/object.h:746,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/pytime.h:6,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/Python.h:85,
#                        from pyflux/arma/arma_recursions.c:4:
#       /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/cpython/object.h:260:30: note: declared here
#         260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#             |                              ^~~~~~~~
#       pyflux/arma/arma_recursions.c:17772:3: warning: ‘tp_print’ is deprecated [-Wdeprecated-declarations]
#       17772 |   __pyx_type___pyx_memoryviewslice.tp_print = 0;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/object.h:746,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/pytime.h:6,
#                        from /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/Python.h:85,
#                        from pyflux/arma/arma_recursions.c:4:
#       /home/gitpod/.pyenv/versions/3.8.13/include/python3.8/cpython/object.h:260:30: note: declared here
#         260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#             |                              ^~~~~~~~
#       pyflux/arma/arma_recursions.c: In function ‘__Pyx__ExceptionSave’:
#       pyflux/arma/arma_recursions.c:19331:21: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19331 |     *type = tstate->exc_type;
#             |                     ^~~~~~~~
#             |                     curexc_type
#       pyflux/arma/arma_recursions.c:19332:22: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19332 |     *value = tstate->exc_value;
#             |                      ^~~~~~~~~
#             |                      curexc_value
#       pyflux/arma/arma_recursions.c:19333:19: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19333 |     *tb = tstate->exc_traceback;
#             |                   ^~~~~~~~~~~~~
#             |                   curexc_traceback
#       pyflux/arma/arma_recursions.c: In function ‘__Pyx__ExceptionReset’:
#       pyflux/arma/arma_recursions.c:19340:24: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19340 |     tmp_type = tstate->exc_type;
#             |                        ^~~~~~~~
#             |                        curexc_type
#       pyflux/arma/arma_recursions.c:19341:25: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19341 |     tmp_value = tstate->exc_value;
#             |                         ^~~~~~~~~
#             |                         curexc_value
#       pyflux/arma/arma_recursions.c:19342:22: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19342 |     tmp_tb = tstate->exc_traceback;
#             |                      ^~~~~~~~~~~~~
#             |                      curexc_traceback
#       pyflux/arma/arma_recursions.c:19343:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19343 |     tstate->exc_type = type;
#             |             ^~~~~~~~
#             |             curexc_type
#       pyflux/arma/arma_recursions.c:19344:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19344 |     tstate->exc_value = value;
#             |             ^~~~~~~~~
#             |             curexc_value
#       pyflux/arma/arma_recursions.c:19345:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19345 |     tstate->exc_traceback = tb;
#             |             ^~~~~~~~~~~~~
#             |             curexc_traceback
#       pyflux/arma/arma_recursions.c: In function ‘__Pyx__GetException’:
#       pyflux/arma/arma_recursions.c:19400:24: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19400 |     tmp_type = tstate->exc_type;
#             |                        ^~~~~~~~
#             |                        curexc_type
#       pyflux/arma/arma_recursions.c:19401:25: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19401 |     tmp_value = tstate->exc_value;
#             |                         ^~~~~~~~~
#             |                         curexc_value
#       pyflux/arma/arma_recursions.c:19402:22: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19402 |     tmp_tb = tstate->exc_traceback;
#             |                      ^~~~~~~~~~~~~
#             |                      curexc_traceback
#       pyflux/arma/arma_recursions.c:19403:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19403 |     tstate->exc_type = local_type;
#             |             ^~~~~~~~
#             |             curexc_type
#       pyflux/arma/arma_recursions.c:19404:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19404 |     tstate->exc_value = local_value;
#             |             ^~~~~~~~~
#             |             curexc_value
#       pyflux/arma/arma_recursions.c:19405:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19405 |     tstate->exc_traceback = local_tb;
#             |             ^~~~~~~~~~~~~
#             |             curexc_traceback
#       pyflux/arma/arma_recursions.c: In function ‘__Pyx__ExceptionSwap’:
#       pyflux/arma/arma_recursions.c:19427:24: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19427 |     tmp_type = tstate->exc_type;
#             |                        ^~~~~~~~
#             |                        curexc_type
#       pyflux/arma/arma_recursions.c:19428:25: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19428 |     tmp_value = tstate->exc_value;
#             |                         ^~~~~~~~~
#             |                         curexc_value
#       pyflux/arma/arma_recursions.c:19429:22: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19429 |     tmp_tb = tstate->exc_traceback;
#             |                      ^~~~~~~~~~~~~
#             |                      curexc_traceback
#       pyflux/arma/arma_recursions.c:19430:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#       19430 |     tstate->exc_type = *type;
#             |             ^~~~~~~~
#             |             curexc_type
#       pyflux/arma/arma_recursions.c:19431:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#       19431 |     tstate->exc_value = *value;
#             |             ^~~~~~~~~
#             |             curexc_value
#       pyflux/arma/arma_recursions.c:19432:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#       19432 |     tstate->exc_traceback = *tb;
#             |             ^~~~~~~~~~~~~
#             |             curexc_traceback
#       In file included from /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/ndarrayobject.h:21,
#                        from /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                        from pyflux/arma/arma_recursions.c:274:
#       At top level:
#       /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include/numpy/__multiarray_api.h:1477:1: warning: ‘_import_array’ defined but not used [-Wunused-function]
#        1477 | _import_array(void)
#             | ^~~~~~~~~~~~~
#       error: Command "gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC -I/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/numpy/core/include -Ibuild/src.linux-x86_64-3.8/numpy/distutils/include -I/home/gitpod/.pyenv/versions/3.8.13/include/python3.8 -c pyflux/arma/arma_recursions.c -o build/temp.linux-x86_64-cpython-38/pyflux/arma/arma_recursions.o -MMD -MF build/temp.linux-x86_64-cpython-38/pyflux/arma/arma_recursions.o.d -msse -msse2 -msse3" failed with exit status 1
#       INFO:
#       ########### EXT COMPILER OPTIMIZATION ###########
#       INFO: Platform      :
#         Architecture: x64
#         Compiler    : gcc
#
#       CPU baseline  :
#         Requested   : 'min'
#         Enabled     : SSE SSE2 SSE3
#         Flags       : -msse -msse2 -msse3
#         Extra checks: none
#
#       CPU dispatch  :
#         Requested   : 'max -xop -fma4'
#         Enabled     : SSSE3 SSE41 POPCNT SSE42 AVX F16C FMA3 AVX2 AVX512F AVX512CD AVX512_KNL AVX512_KNM AVX512_SKX AVX512_CLX AVX512_CNL AVX512_ICL
#         Generated   : none
#       INFO: CCompilerOpt.cache_flush[857] : write cache to path -> /tmp/pip-install-6dab18eh/pyflux_4cf0b35448234aa6b9c4bbb97ffc6914/build/temp.linux-x86_64-cpython-38/ccompiler_opt_cache_ext.py
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> pyflux
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
#
# [notice] A new release of pip available: 22.2 -> 22.2.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
#
# [notice] A new release of pip available: 22.2 -> 22.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import numpy as np
import pandas as pd
import pyflux as pf
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspace/TimeSerires/src/explore.ipynb Cell 3 in <cell line: 4>()
#       <a href='vscode-notebook-cell://eperezvazqu-timeserires-atpwpiemqcy.ws-us59.gitpod.io/workspace/TimeSerires/src/explore.ipynb#ch0000001vscode-remote?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell://eperezvazqu-timeserires-atpwpiemqcy.ws-us59.gitpod.io/workspace/TimeSerires/src/explore.ipynb#ch0000001vscode-remote?line=2'>3</a> import pandas as pd
# ----> <a href='vscode-notebook-cell://eperezvazqu-timeserires-atpwpiemqcy.ws-us59.gitpod.io/workspace/TimeSerires/src/explore.ipynb#ch0000001vscode-remote?line=3'>4</a> import pyflux as pf
#       <a href='vscode-notebook-cell://eperezvazqu-timeserires-atpwpiemqcy.ws-us59.gitpod.io/workspace/TimeSerires/src/explore.ipynb#ch0000001vscode-remote?line=4'>5</a> from datetime import datetime
#       <a href='vscode-notebook-cell://eperezvazqu-timeserires-atpwpiemqcy.ws-us59.gitpod.io/workspace/TimeSerires/src/explore.ipynb#ch0000001vscode-remote?line=5'>6</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pyflux'

# %% [markdown]
# Time serials
#
# https://github.com/oreilly-mlsec/book-resources/blob/master/chapter3/arima-forecasting.ipynb
# https://thecleverprogrammer.com/2020/08/04/arima-model-in-machine-learning/
